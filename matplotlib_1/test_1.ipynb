# %%
import matplotlib.pyplot as plt

year = [1999,2000,2010,2020,2030,2040] # taking as x-axis
gdp = [300.2,543.3,1075.9,2862.5,5979.6,125] # taking as y-axis
plt.plot(year,gdp)
plt.grid()
# Out:
# Matplotlib is building the font cache; this may take a moment.
