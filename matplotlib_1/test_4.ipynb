# %%
import matplotlib.pyplot as plt

n = ['A','B','C','D','E','0F','G']
nums = [10,7,8,9,6,4,5]

plt.bar(range(len(n)),nums)
plt.title("Let's recall how we gave title")
plt.ylabel("Just recall this is how we gave name to y-label")
plt.xticks(range(len(n)),nums)
# Out:
# ([<matplotlib.axis.XTick at 0x7fda84bb82b0>,
# ...
#  [Text(0, 0, '10'),
#   Text(1, 0, '7'),
#   Text(2, 0, '8'),
#   Text(3, 0, '9'),
#   Text(4, 0, '6'),
#   Text(5, 0, '4'),
#   Text(6, 0, '5')])
